# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
smmh = pd.read_csv('/content/drive/MyDrive/smmh.csv')

# %%
smmh.head()
# Out:
#             Timestamp  1. What is your age? 2. Gender 3. Relationship Status  \
# 0  4/18/2022 19:18:47                  21.0      Male      In a relationship
# 1  4/18/2022 19:19:28                  21.0    Female                 Single
# 2  4/18/2022 19:25:59                  21.0    Female                 Single
# 3  4/18/2022 19:29:43                  21.0    Female                 Single
# 4  4/18/2022 19:33:31                  21.0    Female                 Single
#
#   4. Occupation Status 5. What type of organizations are you affiliated with?  \
# 0   University Student                                         University
# 1   University Student                                         University
# 2   University Student                                         University
# 3   University Student                                         University
# 4   University Student                                         University
#
#   6. Do you use social media?  \
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/smmh.csv')

# Dropping the 'Timestamp' column
df.drop(columns=['Timestamp'], inplace=True)

# Drop duplicates
df.drop_duplicates(inplace=True)
# Dropping any rows with missing values
df.dropna(inplace=True)

# %%
df.head()
# Out:
#    1. What is your age? 2. Gender 3. Relationship Status 4. Occupation Status  \
# 0                  21.0      Male      In a relationship   University Student
# 1                  21.0    Female                 Single   University Student
# 2                  21.0    Female                 Single   University Student
# 3                  21.0    Female                 Single   University Student
# 4                  21.0    Female                 Single   University Student
#
#   5. What type of organizations are you affiliated with?  \
# 0                                         University
# 1                                         University
# 2                                         University
# 3                                         University
# 4                                         University
#
#   6. Do you use social media?  \
# 0                         Yes
# 1                         Yes
# 2                         Yes
# 3                         Yes
# ...

# %%
df.to_csv('/content/drive/MyDrive/smmh_cleann.csv', index=False)
smmh_cleann = pd.read_csv('/content/drive/MyDrive/smmh_cleann.csv')

# %%
df.head()
# Out:
#    1. What is your age? 2. Gender 3. Relationship Status 4. Occupation Status  \
# 0                  21.0      Male      In a relationship   University Student
# 1                  21.0    Female                 Single   University Student
# 2                  21.0    Female                 Single   University Student
# 3                  21.0    Female                 Single   University Student
# 4                  21.0    Female                 Single   University Student
#
#   5. What type of organizations are you affiliated with?  \
# 0                                         University
# 1                                         University
# 2                                         University
# 3                                         University
# 4                                         University
#
#   6. Do you use social media?  \
# 0                         Yes
# 1                         Yes
# 2                         Yes
# 3                         Yes
# ...

# %%
# @title 9. How often do you find yourself using Social media without a specific purpose?

from matplotlib import pyplot as plt
df['9. How often do you find yourself using Social media without a specific purpose?'].plot(kind='hist', bins=20, title='9. How often do you find yourself using Social media without a specific purpose?')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title 6. Do you use social media? vs 8. What is the average time you spend on social media every day?

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['8. What is the average time you spend on social media every day?'].value_counts()
    for x_label, grp in df.groupby('6. Do you use social media?')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('6. Do you use social media?')
_ = plt.ylabel('8. What is the average time you spend on social media every day?')

# %%
# Convert column 9 to int
df['9. How often do you find yourself using Social media without a specific purpose?'] = df['9. How often do you find yourself using Social media without a specific purpose?'].map({'Less than an Hour': 0, 'Between 1 and 2 hours': 1, 'Between 2 and 3 hours': 2, 'Between 3 and 4 hours': 3, 'More than 5 hours': 4})
cols_to_convert_to_int = ['18. How often do you feel depressed or down?',
                          '12. On a scale of 1 to 5, how easily distracted are you?',
                          '13. On a scale of 1 to 5, how much are you bothered by worries?',
                          '15. On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?',
                          '16. Following the previous question, how do you feel about these comparisons, generally speaking?',
                          '19. On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?',
                          '20. On a scale of 1 to 5, how often do you face issues regarding sleep?']
# Convert specified columns to integer type
df[cols_to_convert_to_int] = df[cols_to_convert_to_int].apply(lambda x: x.astype(int))
df.columns = df.columns.str.strip()
df.dropna(inplace=True)

# %%
df.head()
# Out:
# Empty DataFrame
# ...

# %%
# Save the cleaned dataset to a new CSV file
# Replace 'fixed_datatypes_dataset.csv' with the desired name for your dataset file with fixed data types



smmh_cleann = pd.read_csv('/content/drive/MyDrive/smmh_cleann.csv')

# %%
#print(df.columns)
smmh_cleann.head()
# Out:
# Empty DataFrame
# ...
